# %%
import pandas as pd
df = pd.read_csv('kc_house_data.csv')

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
import numpy as np

df[df.date == '?']
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %% [markdown]
# #### Insights:
# 1. There is no missing values in the given data set
# 2. date column is object data type, here we need to create new column with integer data type or drop this column from the analysis.
# 3. Id column can be dropped from analysis
# 4. zipcode column can also be dropped from the analysis
# 5. bathroom and bedroom have 0's in them which can be considered as missing value

# %%
df['date1'] = df.date.map(lambda x:x.replace("T000000",''))

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view    ...     sqft_above  sqft_basement  \
# 0      5650     1.0           0     0    ...           1180              0
# 1      7242     2.0           0     0    ...           2170            400
# 2     10000     1.0           0     0    ...            770              0
# 3      5000     1.0           0     0    ...           1050            910
# 4      8080     1.0           0     0    ...           1680              0
#
# ...

# %%
df.date1 = df.date1.astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
df.date1.head()
# Out:
# 0    20141013
# 1    20141209
# 2    20150225
# 3    20141209
# 4    20150218
# Name: date1, dtype: int64

# %%
df_colsDropped = df.drop(['id', 'date'], axis=1)

# %%
df_colsDropped.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df_colsDropped.describe().T
# Out:
#                  count          mean            std           min  \
# price          21613.0  5.400881e+05  367127.196483  7.500000e+04
# bedrooms       21613.0  3.370842e+00       0.930062  0.000000e+00
# bathrooms      21613.0  2.114757e+00       0.770163  0.000000e+00
# sqft_living    21613.0  2.079900e+03     918.440897  2.900000e+02
# sqft_lot       21613.0  1.510697e+04   41420.511515  5.200000e+02
# floors         21613.0  1.494309e+00       0.539989  1.000000e+00
# waterfront     21613.0  7.541757e-03       0.086517  0.000000e+00
# view           21613.0  2.343034e-01       0.766318  0.000000e+00
# condition      21613.0  3.409430e+00       0.650743  1.000000e+00
# grade          21613.0  7.656873e+00       1.175459  1.000000e+00
# sqft_above     21613.0  1.788391e+03     828.090978  2.900000e+02
# sqft_basement  21613.0  2.915090e+02     442.575043  0.000000e+00
# yr_built       21613.0  1.971005e+03      29.373411  1.900000e+03
# ...

# %%
import matplotlib.pyplot as plt
for column in df_colsDropped:
    plt.figure(figsize=(5,5))
    df.boxplot([column])

# %%
#df_colsDropped.bedrooms = df_colsDropped.bedrooms.replace(0,1)
df_colsDropped[df_colsDropped.bathrooms == 0]
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 875    1095000.0         0        0.0         3064      4764     3.5
# 1149     75000.0         1        0.0          670     43377     1.0
# 3119    380000.0         0        0.0         1470       979     3.0
# 5832    280000.0         1        0.0          600     24501     1.0
# 6994   1295650.0         0        0.0         4810     28008     2.0
# 9773    355000.0         0        0.0         2460      8049     2.0
# 9854    235000.0         0        0.0         1470      4800     2.0
# 10481   484000.0         1        0.0          690     23244     1.0
# 14423   139950.0         0        0.0          844      4269     1.0
# 19452   142000.0         0        0.0          290     20875     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 875             0     2          3      7        3064              0
# ...

# %%
#df_colsDropped.bathrooms = df_colsDropped.bathrooms.replace(0,1)

# %%
df_rowsDropped = df_colsDropped
for colname in df_rowsDropped.columns:
    if df_rowsDropped[colname].dtype != 'object':
        sortedCol= np.sort(df_rowsDropped[colname])
        q1,q3=np.percentile(sortedCol,[25,75])
        iqr = q3 - q1
        minCap = (q1-(1.5*iqr))
        maxCap = (q3+(1.5*iqr))
        print(minCap, maxCap)
        #iqr = cancer_df[colname].quantile(.75) - cancer_df[colname].quantile(.25)
        #minCap = cancer_df[colname].quantile(.25) - (1.5 * iqr)
        #maxCap = cancer_df[colname].quantile(.75) + (1.5 * iqr)
        df_rowsDropped = df_rowsDropped[(df_rowsDropped[colname] >= minCap) & (df_rowsDropped[colname] <= maxCap)]
# Out:
# -162625.0 1129575.0
# 1.5 5.5
# 0.0 4.0
# -130.0 3950.0
# -2785.0 17975.0
# -0.5 3.5
# 0.0 0.0
# 0.0 0.0
# 1.5 5.5
# 5.5 9.5
# -18.0 3070.0
# -720.0 1200.0
# 1879.5 2067.5
# 0.0 0.0
# 97905.5 98245.5
# 47.11595 48.02355
# -122.60550000000002 -121.88149999999997
# 450.0 3010.0
# -1222.5 14605.5
# 20126480.5 20164460.5

# %%
df_rowsDropped.shape
# Out:
# (13868, 20)

# %% [markdown]
# #### Insights
# Removal of outliers leads to removal so many rows, which leads to loss of information. This removal of outliers is ignored.

# %%
df_colsDropped.hist(figsize=(15,15),column=df_colsDropped.columns)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a3634d550>,
# ...
#       dtype=object)

# %%
df_colsDropped[df_colsDropped.price < 900000].shape
# Out:
# (19538, 20)

# %% [markdown]
# #### Insights
#
# Most of the price values are less than 900000 on data, so there is imbalance of the in the given data dataset which is right skewed

# %%
import seaborn as sns
sns.pairplot(df_colsDropped, diag_kind='kde')
# Out:
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(15,15))
import seaborn as sn
sn.heatmap(df_colsDropped.corr(), vmin=-1, vmax=1, cmap="RdBu",annot=True)

# %% [markdown]
# #### Insights
# 1. sqft_lot and sqft_lot15 show some correlation between them.
# 2. sqft_above and sqft_liviing also show some correlation between them.
# 3. The rest of the columns are weakly correlated.

# %%
# adding new features
df_colsDropped['living_lot'] = df_colsDropped.sqft_living + df_colsDropped.sqft_lot

# %%
from scipy.stats import zscore
df_colsDropped_scaled  = df_colsDropped.apply(zscore)
X = df_colsDropped_scaled.drop(['price'], axis=1)
y = df_colsDropped_scaled.pop('price')
print(X.sample())
print(X.shape)
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# 5479 -1.473959  -1.447464    -1.110494 -0.219871 -0.915427   -0.087173
#
#           view  condition     grade  sqft_above  sqft_basement  yr_built  \
# 5479 -0.305759   0.907554 -2.260338   -0.879623      -0.658681 -2.145021
#
#       yr_renovated   zipcode       lat      long  sqft_living15  sqft_lot15  \
# 5479     -0.210128 -1.419335 -1.829183 -0.064645      -1.526977   -0.247897
#
#          date1  living_lot
# 5479  1.421923   -0.243504
# (21613, 20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_ = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_, y, shuffle=True, test_size=0.30, random_state=98789)


print(X_train.shape)
print(X_test.shape)
print(y_test.shape)

#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
X_train_std =  X_train #sc.fit_transform(X_train) 
X_test_std =  X_test #sc.fit_transform(X_test)
# Out:
# (15129, 231)
# (6484, 231)
# (6484,)

# %%
# feature extraction

from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X, y)

pd.DataFrame(model.feature_importances_, index=X.columns, 
             columns=['Feature Importance']).sort_values('Feature Importance', ascending=False)
# Out:
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#                Feature Importance
# grade                    0.261078
# sqft_living              0.145481
# lat                      0.133302
# sqft_living15            0.114888
# sqft_above               0.065640
# long                     0.052858
# waterfront               0.041748
# bathrooms                0.032247
# yr_built                 0.031509
# view                     0.023929
# zipcode                  0.020851
# condition                0.010829
# sqft_basement            0.010248
# sqft_lot                 0.009878
# living_lot               0.009038
# date1                    0.008631
# sqft_lot15               0.008393
# bedrooms                 0.007129
# floors                   0.006687
# ...

# %%
from sklearn.linear_model import LinearRegression
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.826599332848376

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8349833520222056

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

alphas = np.array([100000, 10000, 1000, 100, 1,0.1,0.01,0.001,0.0001, 0.00001, 0.000001, 0])

model = Ridge()
grid = GridSearchCV(estimator=model, param_grid=dict(alpha=alphas))
grid.fit(X, y)

print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.6963271594676057
# 100.0
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.191124e-17
#   overwrite_a=True).T

# %%
from sklearn import linear_model
regressor = linear_model.Ridge(alpha = grid.best_estimator_.alpha)
regressor.fit(X_train, y_train)
print('The ridge regressor training set accuracy -- {0}'.format(regressor.score(X_train, y_train)))
print('The ridge regressor Test set accuracy -- {0}'.format(regressor.score(X_test, y_test)))
# Out:
# The ridge regressor training set accuracy -- 0.826432684950985
# The ridge regressor Test set accuracy -- 0.8344066321376795

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
alphas = np.array([100000, 10000, 1000, 100,1,0.1,0.01,0.001,0.0001, 0.00001, 0.000001])

model = Lasso()
grid = GridSearchCV(estimator=model, param_grid=dict(alpha=alphas))
grid.fit(X, y)

print(grid.best_score_)
print(grid.best_estimator_.alpha)
# Out:
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
from sklearn import linear_model
regressor = linear_model.Lasso(alpha = grid.best_estimator_.alpha)
regressor.fit(X_train, y_train)
print('The lasso regressor training set accuracy -- {0}'.format(regressor.score(X_train, y_train)))
print('The lasso regressor test set accuracy -- {0}'.format(regressor.score(X_test, y_test)))
# Out:
# The lasso regressor training set accuracy -- 0.8256856068804704
# The lasso regressor test set accuracy -- 0.8345541631919485
# /Users/malarvizhi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %% [markdown]
# After feature selection through Lasso and Ridge, there is slight increase in accuracy.
